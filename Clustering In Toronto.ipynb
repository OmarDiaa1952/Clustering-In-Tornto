# %%
import numpy as np 
import pandas as pd 
from bs4 import BeautifulSoup
import requests

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(source, 'lxml')

# %%
class Scrapy:
       
        def parse_url(self, url):
            response = requests.get(url)
            soup = BeautifulSoup(response.text, 'lxml')
            return [(self.parse_html_table(table))\
                    for table in soup.find_all('table', class_="wikitable sortable")]  
    
        def parse_html_table(self, table):
            n_columns = 0
            n_rows=0
            column_names = []
            for row in table.find_all('tr'):
                td_tags = row.find_all('td')
                if len(td_tags) > 0:
                    n_rows+=1
                    if n_columns == 0:
                        n_columns = len(td_tags)
                        
                th_tags = row.find_all('th') 
                if len(th_tags) > 0 and len(column_names) == 0:
                    for th in th_tags:
                        column_names.append(th.get_text())
    
            if len(column_names) > 0 and len(column_names) != n_columns:
                raise Exception("Column titles do not match the number of columns")
    
            columns = column_names if len(column_names) > 0 else range(0,n_columns)
            df = pd.DataFrame(columns = columns,
                              index= range(0,n_rows))
            row_marker = 0
            for row in table.find_all('tr'):
                column_marker = 0
                columns = row.find_all('td')
                for column in columns:
                    df.iat[row_marker,column_marker] = column.get_text()
                    column_marker += 1
                if len(columns) > 0:
                    row_marker += 1
                    
            for col in df:
                try:
                    df[col] = df[col].astype(float)
                except ValueError:
                    pass
            
            return df

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
hp = Scrapy()
table = hp.parse_url(url)[0] 
table.head(10)
# Out:
#   Postal Code\n           Borough\n  \
# 0         M1A\n      Not assigned\n
# 1         M2A\n      Not assigned\n
# 2         M3A\n        North York\n
# 3         M4A\n        North York\n
# 4         M5A\n  Downtown Toronto\n
# 5         M6A\n        North York\n
# 6         M7A\n  Downtown Toronto\n
# 7         M8A\n      Not assigned\n
# 8         M9A\n         Etobicoke\n
# 9         M1B\n       Scarborough\n
#
#                                   Neighborhood\n
# 0                                 Not assigned\n
# 1                                 Not assigned\n
# 2                                    Parkwoods\n
# 3                             Victoria Village\n
# 4                    Regent Park, Harbourfront\n
# 5             Lawrence Manor, Lawrence Heights\n
# 6  Queen's Park, Ontario Provincial Government\n
# 7                                 Not assigned\n
# 8      Islington Avenue, Humber Valley Village\n
# 9                               Malvern, Rouge\n

# %%
table = table[table['Borough\n'] != 'Not assigned\n']
table.head(10)
# Out:
#    Postal Code\n           Borough\n  \
# 2          M3A\n        North York\n
# 3          M4A\n        North York\n
# 4          M5A\n  Downtown Toronto\n
# 5          M6A\n        North York\n
# 6          M7A\n  Downtown Toronto\n
# 8          M9A\n         Etobicoke\n
# 9          M1B\n       Scarborough\n
# 11         M3B\n        North York\n
# 12         M4B\n         East York\n
# 13         M5B\n  Downtown Toronto\n
#
#                                    Neighborhood\n
# 2                                     Parkwoods\n
# 3                              Victoria Village\n
# 4                     Regent Park, Harbourfront\n
# 5              Lawrence Manor, Lawrence Heights\n
# 6   Queen's Park, Ontario Provincial Government\n
# 8       Islington Avenue, Humber Valley Village\n
# 9                                Malvern, Rouge\n
# 11                                    Don Mills\n
# 12              Parkview Hill, Woodbine Gardens\n
# 13                     Garden District, Ryerson\n

# %%
print(list(table))
table = table.replace('\n',' ', regex=True)
table.head(10)
# Out:
# ['Postal Code\n', 'Borough\n', 'Neighborhood\n']
#    Postal Code\n          Borough\n  \
# 2           M3A         North York
# 3           M4A         North York
# 4           M5A   Downtown Toronto
# 5           M6A         North York
# 6           M7A   Downtown Toronto
# 8           M9A          Etobicoke
# 9           M1B        Scarborough
# 11          M3B         North York
# 12          M4B          East York
# 13          M5B   Downtown Toronto
#
#                                   Neighborhood\n
# 2                                     Parkwoods
# 3                              Victoria Village
# 4                     Regent Park, Harbourfront
# 5              Lawrence Manor, Lawrence Heights
# 6   Queen's Park, Ontario Provincial Government
# 8       Islington Avenue, Humber Valley Village
# 9                                Malvern, Rouge
# 11                                    Don Mills
# 12              Parkview Hill, Woodbine Gardens
# 13                     Garden District, Ryerson

# %%
table = table[table['Neighborhood\n'] != 'Not assigned\n']
table.head(10)
# Out:
#    Postal Code\n          Borough\n  \
# 2           M3A         North York
# 3           M4A         North York
# 4           M5A   Downtown Toronto
# 5           M6A         North York
# 6           M7A   Downtown Toronto
# 8           M9A          Etobicoke
# 9           M1B        Scarborough
# 11          M3B         North York
# 12          M4B          East York
# 13          M5B   Downtown Toronto
#
#                                   Neighborhood\n
# 2                                     Parkwoods
# 3                              Victoria Village
# 4                     Regent Park, Harbourfront
# 5              Lawrence Manor, Lawrence Heights
# 6   Queen's Park, Ontario Provincial Government
# 8       Islington Avenue, Humber Valley Village
# 9                                Malvern, Rouge
# 11                                    Don Mills
# 12              Parkview Hill, Woodbine Gardens
# 13                     Garden District, Ryerson

# %%
df = table.groupby(['Postal Code\n','Borough\n'])['Neighborhood\n'].apply(lambda x: ", ".join(x.astype(str))).reset_index()
df = df.sample(frac=1).reset_index(drop=True)
df.head(10)
# Out:
#   Postal Code\n          Borough\n                             Neighborhood\n
# 0          M5B   Downtown Toronto                   Garden District, Ryerson
# 1          M4K       East Toronto               The Danforth West, Riverdale
# 2          M5G   Downtown Toronto                         Central Bay Street
# 3          M5X   Downtown Toronto     First Canadian Place, Underground city
# 4          M6L         North York   North Park, Maple Leaf Park, Upwood Park
# 5          M5W   Downtown Toronto                             Stn A PO Boxes
# 6          M2M         North York                    Willowdale, Newtonbrook
# 7          M3B         North York                                  Don Mills
# 8          M1E        Scarborough          Guildwood, Morningside, West Hill
# 9          M4E       East Toronto                                The Beaches

# %%
print(df.shape)
# Out:
# (103, 3)

# %%
url2="https://cocl.us/Geospatial_data"
geo_data=pd.read_csv(url2)
geo_data.head(10)
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476
# 5         M1J  43.744734 -79.239476
# 6         M1K  43.727929 -79.262029
# 7         M1L  43.711112 -79.284577
# 8         M1M  43.716316 -79.239476
# 9         M1N  43.692657 -79.264848

# %%
full_table=df
print(list(df))
print(list(geo_data))
condition =  geo_data["Postal Code"] == df["Postal Code\n"]
df.loc[~condition, 'Latitude'] = geo_data["Latitude"]
df.loc[~condition, 'Longitude'] = geo_data["Longitude"]
df
# Out:
# ['Postal Code\n', 'Borough\n', 'Neighborhood\n']
# ['Postal Code', 'Latitude', 'Longitude']
#     Postal Code\n          Borough\n  \
# 0            M5B   Downtown Toronto
# 1            M4K       East Toronto
# 2            M5G   Downtown Toronto
# 3            M5X   Downtown Toronto
# 4            M6L         North York
# 5            M5W   Downtown Toronto
# 6            M2M         North York
# 7            M3B         North York
# 8            M1E        Scarborough
# 9            M4E       East Toronto
# 10           M6M               York
# 11           M1S        Scarborough
# 12           M5M         North York
# 13           M6J       West Toronto
# 14           M1H        Scarborough
# 15           M4P    Central Toronto
# 16           M4H          East York
# 17           M2N         North York
# 18           M9M         North York
# 19           M9C          Etobicoke
# 20           M2J         North York
# 21           M3H         North York
# 22           M5V   Downtown Toronto
# 23           M8X          Etobicoke
# 24           M4A         North York
# 25           M8Z          Etobicoke
# 26           M6K       West Toronto
# 27           M1C        Scarborough
# 28           M4Y   Downtown Toronto
# 29           M9A          Etobicoke
# ..            ...                ...
# 73           M1P        Scarborough
# 74           M2R         North York
# 75           M6H       West Toronto
# 76           M4T    Central Toronto
# 77           M7R        Mississauga
# 78           M6P       West Toronto
# 79           M4S    Central Toronto
# 80           M5E   Downtown Toronto
# 81           M6C               York
# 82           M1J        Scarborough
# 83           M6B         North York
# 84           M7A   Downtown Toronto
# 85           M3A         North York
# 86           M2H         North York
# 87           M5C   Downtown Toronto
# 88           M1V        Scarborough
# 89           M1G        Scarborough
# 90           M4L       East Toronto
# 91           M4C          East York
# 92           M5A   Downtown Toronto
# 93           M1X        Scarborough
# 94           M5T   Downtown Toronto
# 95           M3N         North York
# 96           M5K   Downtown Toronto
# 97           M5S   Downtown Toronto
# 98           M5N    Central Toronto
# 99           M6N               York
# 100          M3K         North York
# 101          M5R    Central Toronto
# 102          M6E               York
#
#                                         Neighborhood\n   Latitude  Longitude
# 0                            Garden District, Ryerson   43.806686 -79.194353
# 1                        The Danforth West, Riverdale   43.784535 -79.160497
# 2                                  Central Bay Street   43.763573 -79.188711
# 3              First Canadian Place, Underground city   43.770992 -79.216917
# 4            North Park, Maple Leaf Park, Upwood Park   43.773136 -79.239476
# 5                                      Stn A PO Boxes   43.744734 -79.239476
# 6                             Willowdale, Newtonbrook   43.727929 -79.262029
# 7                                           Don Mills   43.711112 -79.284577
# 8                   Guildwood, Morningside, West Hill   43.716316 -79.239476
# 9                                         The Beaches   43.692657 -79.264848
# 10   Del Ray, Mount Dennis, Keelsdale and Silverthorn   43.757410 -79.273304
# 11                                          Agincourt   43.750072 -79.295849
# 12                  Bedford Park, Lawrence Manor East   43.794200 -79.262029
# 13                           Little Portugal, Trinity   43.781638 -79.304302
# 14                                          Cedarbrae   43.815252 -79.284577
# 15                                   Davisville North   43.799525 -79.318389
# 16                                   Thorncliffe Park   43.836125 -79.205636
# 17                        Willowdale, Willowdale East   43.803762 -79.363452
# 18                                   Humberlea, Emery   43.778517 -79.346556
# 19   Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.786947 -79.385975
# 20                       Fairview, Henry Farm, Oriole   43.757490 -79.374714
# 21    Bathurst Manor, Wilson Heights, Downsview North   43.789053 -79.408493
# 22   CN Tower, King and Spadina, Railway Lands, Har...  43.770120 -79.408493
# 23      The Kingsway, Montgomery Road, Old Mill North   43.752758 -79.400049
# 24                                   Victoria Village   43.782736 -79.442259
# 25   Mimico NW, The Queensway West, South of Bloor,...  43.753259 -79.329656
# 26       Brockton, Parkdale Village, Exhibition Place   43.745906 -79.352188
# 27             Rouge Hill, Port Union, Highland Creek   43.725900 -79.340923
# 28                               Church and Wellesley   43.754328 -79.442259
# 29            Islington Avenue, Humber Valley Village   43.767980 -79.487262
# ..                                                 ...        ...        ...
# 73   Dorset Park, Wexford Heights, Scarborough Town...  43.693781 -79.428191
# 74                        Willowdale, Willowdale West   43.689026 -79.453512
# 75                       Dufferin, Dovercourt Village   43.669542 -79.422564
# 76                        Moore Park, Summerhill East   43.669005 -79.442259
# 77              Canada Post Gateway Processing Centre   43.647927 -79.419750
# 78                      High Park, The Junction South   43.636847 -79.428191
# 79                                         Davisville   43.713756 -79.490074
# 80                                        Berczy Park   43.691116 -79.476013
# 81                                 Humewood-Cedarvale   43.673185 -79.487262
# 82                                Scarborough Village   43.661608 -79.464763
# 83                                          Glencairn   43.648960 -79.456325
# 84        Queen's Park, Ontario Provincial Government   43.651571 -79.484450
# 85                                          Parkwoods   43.662301 -79.389494
# 86                                  Hillcrest Village   43.636966 -79.615819
# 87                                     St. James Town   43.662744 -79.321558
# 88   Milliken, Agincourt North, Steeles East, L'Amo...  43.605647 -79.501321
# 89                                             Woburn   43.602414 -79.543484
# 90                     India Bazaar, The Beaches West   43.653654 -79.506944
# 91                                   Woodbine Heights   43.636258 -79.498509
# 92                          Regent Park, Harbourfront   43.628841 -79.520999
# 93                                        Upper Rouge   43.667856 -79.532242
# 94          Kensington Market, Chinatown, Grange Park   43.650943 -79.554724
# 95                                          Downsview   43.643515 -79.577201
# 96           Toronto Dominion Centre, Design Exchange   43.756303 -79.565963
# 97                     University of Toronto, Harbord   43.724766 -79.532242
# 98                                           Roselawn   43.706876 -79.518188
# 99                      Runnymede, The Junction North   43.696319 -79.532242
# 100                                         Downsview   43.688905 -79.554724
# 101               The Annex, North Midtown, Yorkville   43.739416 -79.588437
# 102                               Caledonia-Fairbanks   43.706748 -79.594054
#
# [103 rows x 5 columns]

# %%
# !pip install folium
from geopy.geocoders import Nominatim 
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/a4/f0/44e69d50519880287cc41e7c8a6acc58daa9a9acf5f6afc52bcc70f69a6d/folium-0.11.0-py2.py3-none-any.whl (93kB)
#      |████████████████████████████████| 102kB 7.6MB/s ta 0:00:011
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/13/fb/9eacc24ba3216510c6b59a4ea1cd53d87f25ba76237d7f4393abeaf4c94e/branca-0.4.1-py3-none-any.whl
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.1 folium-0.11.0

# %%
address = 'Toronto'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   app.launch_new_instance()

# %%
map_geo = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, label in zip(full_table['Latitude'], full_table['Longitude'], full_table['Neighborhood\n']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_geo)  
    
map_geo
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
